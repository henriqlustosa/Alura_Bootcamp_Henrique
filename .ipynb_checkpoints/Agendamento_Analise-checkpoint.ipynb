# %% [markdown]
# # Análise de Dados - TABNET DataSus
#
# Análise de dados utilizados no TabNet (Sistema de acesso ao Banco de Dados do DataSUS). Relacionado aos gastos hospitalares SIH/SUS a partir do ano de 2008.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
dados = pd.read_csv("DataBase/Arquivo_Base.csv",engine ="python",skipfooter = 1, encoding = "utf 16", sep = ";", thousands =".", decimal= ",")
# setting first name as index column
dados.set_index("Unidade da Federação", inplace = True)

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.head()
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1388528.39  2931283.42  1541682.52  1525314.96
# 12 Acre                902416.00  1497206.26  1794028.48  1730469.42
# 13 Amazonas           4735529.42  7118990.57  8196635.49  8259378.42
# 14 Roraima             657889.53   777939.31   718688.03   839994.39
# 15 Pará              18864744.11 19553758.20 21937342.70 20842829.69
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 11 Rondônia           1645953.84  1406150.68  3065279.01  3231494.61
# 12 Acre               1819443.92  1828496.00  2511754.59  2089107.14
# 13 Amazonas           7831399.90  8477273.62  9368858.72  9352532.70
# 14 Roraima             862347.96   832440.66   996693.09   894271.18
# 15 Pará              23249952.88 23240687.56 24002223.56 23341218.03
#
#                         2008/Set    2008/Out  ...    2019/Dez    2020/Jan  \
# ...

# %%
dados.shape
# Out:
# (27, 153)

# %%
dados.describe()
# Out:
#          2008/Jan     2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# count       27.00        27.00        27.00        27.00        27.00
# mean  15126846.64  22710158.12  24594187.35  25431957.83  26511245.91
# std   19159188.30  30879444.07  32516725.69  33339066.25  37540771.63
# min     657889.53    777939.31    718688.03    839994.39    862347.96
# 25%    4740724.30   7060731.59   8041439.31   8526744.11   8531522.65
# 50%    7985142.43  10079928.25  10352238.59  11253833.56  12215107.11
# 75%   17684828.78  25693265.33  29357964.23  32741327.52  31376220.41
# max   91678473.48 148677526.82 156087269.23 161227125.43 187119397.64
#
#           2008/Jun     2008/Jul     2008/Ago     2008/Set     2008/Out  ...  \
# count        27.00        27.00        27.00        27.00        27.00  ...
# mean   27858576.43  28332973.51  27800320.31  27887505.26  27148854.29  ...
# std    38676893.04  39292968.91  37748913.80  38226540.65  36671387.56  ...
# ...

# %%
dados["2008/Fev"].mean()
# Out:
# 22710158.118888885

# %%
dados.plot( y="2008/Ago",use_index=True)

# %%
dados.tail()
# Out:
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 43 Rio Grande do Sul  30931325.46 57363420.01 51547794.07 56673338.49
# 50 Mato Grosso do Sul  5377392.11  7002472.61  8423933.19  8797487.68
# 51 Mato Grosso         4795299.01  8684882.23  7886243.14  8794109.79
# 52 Goiás              15310637.29 22258668.68 21442515.75 20921212.45
# 53 Distrito Federal    4745919.19  7632480.67  9647203.26 11098732.99
#
#                          2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 43 Rio Grande do Sul  48397733.07 52413429.62 56636376.98 56113054.70
# 50 Mato Grosso do Sul  9770421.80 10905392.18 10249299.82  9671553.45
# 51 Mato Grosso         9231645.40 10221763.77  9163314.28  9243148.81
# 52 Goiás              21615970.67 18270043.87 20540517.13 20650730.67
# 53 Distrito Federal   12891719.72 12850125.67 12565646.74 13710857.89
#
#                          2008/Set    2008/Out  ...    2019/Dez    2020/Jan  \
# ...

# %%
dados.plot( y="2008/Ago", kind="bar",figsize=(9,6), use_index = True)

# %%
ax = dados.plot( y="2008/Ago", kind="bar",figsize=(9,6), use_index = True)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")
plt.show()

# %% [markdown]
# ### Desafio: escolher um título mais descritivo, que passe a mensagem adequada.
# ### Desafio: faça a mesma análise para o mês mais recente.

# %%
def assess_NA(data):
    """
    Returns a pandas dataframe denoting the total number of NA values and the percentage of NA values in each column.
    The column names are noted on the index.
    
    Parameters
    ----------
    data: dataframe
    """
    # pandas series denoting features and the sum of their null values
    null_sum = data.isnull().sum()# instantiate columns for missing data
    total = null_sum.sort_values(ascending=False)
    percent = ( ((null_sum / len(data.index))*100).round(2) ).sort_values(ascending=False)
    
    # concatenate along the columns to create the complete dataframe
    df_NA = pd.concat([total, percent], axis=1, keys=['Number of NA', 'Percent NA'])
    
    # drop rows that don't have any missing data; omit if you want to keep all rows
    df_NA = df_NA[ (df_NA.T != 0).any() ] # ndarray.T The transposed array. [[1,2,3]] -> [[1][2][3]]
    
    return df_NA

# %%
assess_NA(dados)
# Out:
# Empty DataFrame
# Columns: [Number of NA, Percent NA]
# Index: []

# %%
dados_atend = pd.read_csv("DataBase/Arquivo_Valor_Atendimento.csv",engine ="python",skiprows = 3,skipfooter =10, encoding = "ISO 8859-1", sep = ";", thousands =".", decimal= ",")

# %%
dados_atend.head()
# Out:
#   Região/Unidade da Federação 1989 1991 1992 1993 1994 1995 1996 1997 1998  \
# 0                Região Norte    -    -    -    -    -    -    -    -    -
# 1                 .. Rondônia    -    -    -    -    -    -    -    -    -
# 2                     .. Acre    -    -    -    -    -    -    -    -    -
# 3                 .. Amazonas    -    -    -    -    -    -    -    -    -
# 4                  .. Roraima    -    -    -    -    -    -    -    -    -
#
#    ...         2012         2013         2014         2015         2016  \
# 0  ... 654252235.58 697140808.84 726059319.76 752664076.48 766941040.11
# 1  ...  52301055.10  66729484.10  82257890.98  88428027.15  91623322.06
# 2  ...  34119460.43  33784031.38  35828191.77  37212305.04  38899136.05
# 3  ... 122916860.05 124394890.31 125653016.96 151951929.99 148594724.62
# 4  ...  20131420.61  20992961.13  21581368.46  24253816.82  27134105.91
#
#           2017         2018         2019         2020         Total
# ...

# %%
dados_atend.shape
# Out:
# (34, 33)

# %%
dados_atend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Região/Unidade da Federação  34 non-null     object
#  1   1989                         33 non-null     object
#  2   1991                         33 non-null     object
#  3   1992                         33 non-null     object
#  4   1993                         33 non-null     object
#  5   1994                         33 non-null     object
#  6   1995                         33 non-null     object
#  7   1996                         33 non-null     object
#  8   1997                         33 non-null     object
#  9   1998                         33 non-null     object
#  10  1999                         33 non-null     object
#  11  2000                         33 non-null     object
#  12  2001                         33 non-null     object
# ...

# %%
assess_NA(dados_atend)
# Out:
#        Number of NA  Percent NA
# Total             1        2.94
# 2004              1        2.94
# 1989              1        2.94
# 1991              1        2.94
# 1992              1        2.94
# 1993              1        2.94
# 1994              1        2.94
# 1995              1        2.94
# 1996              1        2.94
# 1997              1        2.94
# 1998              1        2.94
# 1999              1        2.94
# 2000              1        2.94
# 2001              1        2.94
# 2002              1        2.94
# 2003              1        2.94
# 2005              1        2.94
# 2020              1        2.94
# 2006              1        2.94
# 2007              1        2.94
# 2008              1        2.94
# 2009              1        2.94
# 2010              1        2.94
# 2011              1        2.94
# 2012              1        2.94
# 2013              1        2.94
# 2014              1        2.94
# 2015              1        2.94
# ...

# %%
assess_NA(dados_atend)
# Out:
#        Number of NA  Percent NA
# Total             1        2.94
# 2004              1        2.94
# 1989              1        2.94
# 1991              1        2.94
# 1992              1        2.94
# 1993              1        2.94
# 1994              1        2.94
# 1995              1        2.94
# 1996              1        2.94
# 1997              1        2.94
# 1998              1        2.94
# 1999              1        2.94
# 2000              1        2.94
# 2001              1        2.94
# 2002              1        2.94
# 2003              1        2.94
# 2005              1        2.94
# 2020              1        2.94
# 2006              1        2.94
# 2007              1        2.94
# 2008              1        2.94
# 2009              1        2.94
# 2010              1        2.94
# 2011              1        2.94
# 2012              1        2.94
# 2013              1        2.94
# 2014              1        2.94
# 2015              1        2.94
# ...
